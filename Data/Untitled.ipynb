# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("CenterFreqResponse.csv")[20:]

# %%
data.head()
# Out:
#     freq  velocity     force
# 20  10.0  0.003777 -0.079909
# 21  10.5  0.003396 -0.075494
# 22  11.0  0.003213 -0.072489
# 23  11.5  0.003877 -0.069410
# 24  12.0  0.004042 -0.066886

# %%
data["Young"] = data["velocity"]+ 1j*data["force"]

# %%
plt.plot(data["freq"], 20*np.log10(abs(data["Young"])))
plt.show()
